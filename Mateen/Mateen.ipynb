# %%
from google.colab import drive
drive.mount('/content/drive')
# Create a folder in your Drive for your projects (optional)
# This command will create a folder named 'Colab_Projects' in the root of your Drive
# !mkdir -p '/content/drive/My Drive/Colab_Projects'

# Change the current working directory to the new folder
# %cd '/content/drive/My Drive/Colab_Projects'

# Now, clone the Mateen repository into this folder
# !git clone https://github.com/ICL-ml4csec/Mateen.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab_Projects
# fatal: destination path 'Mateen' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/Colab_Projects/Mateen/
# !python Mateen.py
# Out:
# /content/drive/MyDrive/Colab_Projects/Mateen
# Current directory: /content/drive/MyDrive/Colab_Projects/Mateen
# Python path includes MateenUtils: False
# ✓ nsl_preprocessing imported successfully!
# ✓ utils imported successfully!
# ✓ main imported successfully!
# === Running Mateen with Enhanced NSL-KDD ===
# Current directory: /content/drive/MyDrive/Colab_Projects/Mateen
# Dataset: NSLKDD
# Window size: 50000
# Features: 15
# Selection budget: 0.01
#
# 1. Loading enhanced preprocessed NSL-KDD data...
# === Universal NSL-KDD Preprocessing ===
# 1. Loading and cleaning data...
#    Original: Train (125973, 39), Test (22544, 39)
# 2. Engineering features...
#    After engineering: (125973, 54)
# 3. Handling outliers...
# 4. Encoding categorical features...
# 5. Scaling features...
# 6. Selecting top 15 features...
# Selected 15 features using consensus:
#    1. root_shell
#    2. duration
#    3. num_root
#    4. num_file_creations
#    5. num_shells
#    6. num_access_files
# ...

# %%
# Change to your working directory in Google Drive
# %cd /content/drive/My Drive/Colab_Projects

# Clone the repository you want to add the folder to
# !git clone https://Micro-Maxis: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@github.com/Micro-Maxis/Intrusion-detection-system-dli.git
# Out:
# Cloning into 'Mateen_revised'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 2.59 MiB | 3.40 MiB/s, done.
